# %% [markdown]
# # **PYTHON**

# %%
x=6
print(x)
# Out:
# 6

# %% [markdown]
# ## **DATA TYPES**
#
# ---

# %% [markdown]
# ### to find type

# %%
x=795
y=26
z=x*y
print(z)
# Out:
# 20670

# %%
payment_per_day=795
days_of_working=26
total_salary=payment_per_day*days_of_working
print(total_salary)
# Out:
# 20670

# %%
x,y,z="fruits","markets","computer"
'''jkl
jklj
lkjl;'''
print(x,y,z) # print used to show output
# Out:
# fruits markets computer

# %%
x="hello python"
y=123
z=1.23
a=True
b="1234"
print(x,y,z,a,b)
# Out:
# hello python 123 1.23 True 1234

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
print(type(y))
# Out:
# <class 'int'>

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
print(type(a))
# Out:
# <class 'bool'>

# %%
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# ### conversion

# %%
x=123
print(x)
# Out:
# 123

# %%
print(str(x))
# Out:
# 123

# %% [markdown]
# ### adding of two strings(concatination)

# %%
x="hello"
y="python"
var=x+y
print(var)
# Out:
# hellopython

# %%
print(type(var))
# Out:
# <class 'str'>

# %%
x="133545"
y=12345
z=int(x)
a=z+y
print(a)
# Out:
# 145890

# %%
x="hello"
z=int(x)
print(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-14-448073129.py in <cell line: 0>()
#       1 x="hello"
# ----> 2 z=int(x)
#       3 print(z)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %% [markdown]
# # **1.STRING**

# %%
'hello'
print('hello')
# Out:
# hello

# %%
"hello"
print("hello")
# Out:
# hello

# %% [markdown]
# ### **string as array**

# %%
x="array"
print(x[0])
# Out:
# a

# %%
print(x[1])
# Out:
# r

# %% [markdown]
# ### **length of the string**

# %%
x="hello programmer"
print(len(x))
# Out:
# 16

# %% [markdown]
# ### **to check certain phrase or character present in string**

# %%
Text="hello,let's start coding"
print("start" in Text)
# Out:
# True

# %%
print("hello" in Text)
# Out:
# True

# %% [markdown]
# ### **not present in string**

# %%
voice="this is an automated voice by siri"
print("hello" not in voice)
# Out:
# True

# %% [markdown]
# ### **python slicing**

# %%
xyz="hy my name is python"
print(xyz[2:10])
# Out:
#  my name

# %%
S="ABCDEFGHI"
print(S[2:7])
# Out:
# CDEFG

# %%
word="hello python"
print(word[1:])
# Out:
# ello python

# %%
x="python"
print(x[-1])
# Out:
# n

# %%
b="Hello,world!"
print(b[-5:-2])
# Out:
# orl

# %% [markdown]
# ### **uppercase**

# %%
word="hello python"
print(word.upper())
# Out:
# HELLO PYTHON

# %% [markdown]
# ### lowercase

# %%
word="HELLO PYTHON"
print(word.lower())
# Out:
# hello python

# %% [markdown]
# ### **remove whitespace**

# %%
a=" Hello,World!"
print(a.strip())#strip function
# Out:
# Hello,World!

# %% [markdown]
# ### **replace a letter**

# %%
a="Hello,World!"
print(a.replace("H","J")) #replace function
# Out:
# Jello,World!

# %% [markdown]
# ### **split method**

# %%
a="Hello, world!"
print(a.split(","))
# Out:
# ['Hello', ' world!']

# %% [markdown]
# ### **concatenation**

# %%
A="hello"
B="python"
v=A+B
print(v)
# Out:
# hellopython

# %%
a=1
b=1
v=a+b
print(v)
# Out:
# 2

# %%
a='1'
b='1'
v=a+b
print(v)
# Out:
# 11

# %% [markdown]
# ### **string format**

# %%
age=36
txt="My name is John,and I am"+age
print(txt) #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3643226896.py in <cell line: 0>()
#       1 age=36
# ----> 2 txt="My name is John and I am"+age
#       3 print(txt) #error
#
# TypeError: can only concatenate str (not "int") to str

# %%
age=36
txt="My name is John,and Iam {}"
print(txt.format(age)) #format function
# Out:
# My name is John,and Iam 36

# %%
amount=3212
orderno=4776
quantity=10
myorder="I want {} of my order {} for {} rupees"
print(myorder.format(quantity,orderno,amount))
# Out:
# I want 10 of my order 4776 for 3212 rupees

# %% [markdown]
# ### **escape character**

# %%
txt="we are the so-called\'vikings\'from the north."
print(txt) # \-single quote
# Out:
# we are the so-called'vikings'from the north.

# %%
txt="we are the so-called \nvikings from the north."
print(txt) # \n-new line
# Out:
# we are the so-called
# vikings from the north.

# %%
txt="we are the so-called \t vikings from the north."
print(txt) # \t-tab space
# Out:
# we are the so-called 	 vikings from the north.

# %%
txt="we are the so-called \b vikings from the north."
print(txt) # \b-backspace
# Out:
#  vikings from the north.

# %% [markdown]
# # **2.PYTHON BOOLEANS**

# %%
print(10==10)
# Out:
# True

# %%
print(10<9)
# Out:
# False

# %%
print(10==100)
# Out:
# False

# %%
print(bool("hello"))
# Out:
# True

# %%
print(bool("100"))
# Out:
# True

# %%
print(bool("python"))
# Out:
# True

# %%
print(bool(["apple","cherry","banana"]))
# Out:
# True

# %%
print(bool(False))
# Out:
# False

# %%
print(bool(None))
# Out:
# False

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(()))
# Out:
# False

# %%
print(bool([]))
# Out:
# False

# %%
x=200
print(isinstance(x,int))
# Out:
# True

# %% [markdown]
# ## **PYTHON OPERATORS**

# %% [markdown]
# ## **1) ARITHMETIC OPERATORS**

# %% [markdown]
# ### **1.addition(+)**

# %%
x=5
y=6
print(x+y)
# Out:
# 11

# %% [markdown]
# ### **2.subtraction(-)**

# %%
x=10
y=5
print(x-y)
# Out:
# 5

# %% [markdown]
# ### **3.multiplication**

# %%
x=5
y=6
print(x*y)
# Out:
# 30

# %% [markdown]
# ### **4.exponention**

# %%
x=2
y=3
print(x**y)
# Out:
# 8

# %% [markdown]
# ### **5.division**

# %%
x=6
y=3
print(x/y)
# Out:
# 2.0

# %% [markdown]
# ### **6.floor division**

# %%
x=6
y=5
print(x//y)
# Out:
# 1

# %% [markdown]
# ### **7.modulus**

# %%
x=11
y=3
print(x%y)
# Out:
# 2

# %% [markdown]
# ## **2) ASSIGNMENT OPERATORS**

# %%
x=5
print(x) # =
# Out:
# 5

# %%
x=5
x+=5
print(x) # +=
# Out:
# 10

# %%
x=5
x-=2
print(x) # -=
# Out:
# 3

# %%
x=2
x*=3
print(x) # *=
# Out:
# 6

# %%
x=6
x/=3
print(x) # /=
# Out:
# 2.0

# %%
x=6
x//=5
print(x) # //=
# Out:
# 1

# %%
x=11
x%=3
print(x) # %=
# Out:
# 2

# %%
x=11
x&=3
print(x) # &=
# Out:
# 3

# %%
x=3
x|=4
print(x) # |=
# Out:
# 7

# %%
x=5
x^=2
print(x) # ^=
# Out:
# 7

# %%
x=5
x>>=2
print(x) # >>=
# Out:
# 1

# %%
x=5
x<<=2
print(x) # <<=
# Out:
# 20

# %% [markdown]
# ## **3) LOGICAL OPERATORS**

# %%
x=5
y=6
print(x>1 and y<10)
# Out:
# True

# %%
x=5
y=6
print(x>5 or y<10)
# Out:
# True

# %%
x=5
print(not x>1)
# Out:
# False

# %% [markdown]
# ## **4) IDENTITY OPERATORS**

# %%
x=5
y=6
print(x is y)
# Out:
# False

# %%
x=5
y=6
print(x is not y)
# Out:
# True

# %% [markdown]
# ## **5) MEMBERSHIP TEST OPERATORS**

# %%
nums=[1,2,3,4,5]
print(1 in nums)
# Out:
# True

# %%
print(10 in nums)
# Out:
# False

# %%
print('str' in "string")
# Out:
# True

# %%
nums=[1,2,3,4,5]
print(1 not in nums)
# Out:
# False

# %%
print(10 not in nums)
# Out:
# True

# %%
print('str' not in "string")
# Out:
# False

# %% [markdown]
# ## **6) BITWISE OPERATORS**

# %%
x=5
y=10
z=x&y
print(z)
# Out:
# 0

# %%
x=5
y=10
z=x|y
print(z)
# Out:
# 15

# %%
x=5
y=10
z=x^y
print(z)
# Out:
# 15

# %% [markdown]
# # **3.LISTS**

# %%
fruits=["banana","apple","orange"]
print(fruits)
# Out:
# ['banana', 'apple', 'orange']

# %%
print(fruits[1]) #index
# Out:
# apple

# %% [markdown]
# **range of items**

# %%
fruits=["apple","orange","mango","apple","kiwi","pineapple"]
print(fruits[1:5])
# Out:
# ['orange', 'mango', 'apple', 'kiwi']

# %%
print(fruits[:5])
# Out:
# ['apple', 'orange', 'mango', 'apple', 'kiwi']

# %%
print(fruits[1:])
# Out:
# ['orange', 'mango', 'apple', 'kiwi', 'pineapple']

# %%
fruits[1]="banana"
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'apple', 'kiwi', 'pineapple']

# %%
fruits[2:4]=["watermelon","greenapple"]
print(fruits)
# Out:
# ['apple', 'banana', 'watermelon', 'greenapple', 'kiwi', 'pineapple']

# %%
fruits=["apple","banana","orange"]
fruits[2:]=["watermelon","kiwi"]
print(fruits)
# Out:
# ['apple', 'banana', 'watermelon', 'kiwi']

# %%
fruits=["apple","banana","orange"]
fruits[1:2]=["kiwi"]
print(fruits)
# Out:
# ['apple', 'kiwi', 'orange']

# %%
fruits=["apple","banana","cherry"]
fruits.insert(1,"orange")
print(fruits) #insert() function
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
fruits=["apple","banana","cherry"]
fruits.append("orange")
print(fruits)  #append() function
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits=["apple","banana","cherry"]
fruits2=["mango","pineapple","papaya"]
fruits.extend(fruits2)
print(fruits)  #extend() function
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
fruits=["apple","banana","cherry"]
fruits.remove("apple")
print(fruits) # remove() function
# Out:
# ['banana', 'cherry']

# %%
fruits=["apple","banana","cherry"]
fruits.pop(1)
print(fruits) #pop() function
# Out:
# ['apple', 'cherry']

# %%
fruits=["apple","banana","cherry"]
del fruits[1]
print(fruits) # del() function
# Out:
# ['apple', 'cherry']

# %%
fruits=["apple","banana","cherry"]
fruits.clear()
print(fruits) # clear() function
# Out:
# []

# %%
fruits=["apple","banana","cherry"]
myfruits=fruits.copy()
print(myfruits) #copying of a list
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# # **4.TUPLES**

# %%
fruits=("apple","orange","kiwi")
print(fruits)
# Out:
# ('apple', 'orange', 'kiwi')

# %%
print(len(fruits))
# Out:
# 3

# %%
print(type(fruits))
# Out:
# <class 'tuple'>

# %%
variety=("abc",34,True,40,"male")
print(type(variety))
# Out:
# <class 'tuple'>

# %%
fruits=("apple","banana","cherry")
print(fruits[1])
# Out:
# banana

# %%
print(fruits[-1])
# Out:
# cherry

# %%
fruits=("apple","banana","cherry","orange","kiwi","melon")
print(fruits[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon')

# %%
x=("apple","banana","cherry")
y=list(x)
y[1]="watermelon"
x=tuple(y)
print(x)
# Out:
# ('apple', 'watermelon', 'cherry')

# %%
fruits=("apple","banana","cherry")
(green,yellow,red)=fruits
print(green)
# Out:
# apple

# %%
print(yellow)
# Out:
# banana

# %%
print(red)
# Out:
# cherry

# %% [markdown]
# # **5.SETS**

# %%
fruits={"apple","banana","cherry"}
print(fruits)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
print("banana" in fruits)
# Out:
# True

# %%
fruits={"apple","banana","cherry"}
fruits.add("orange")
print(fruits)
# Out:
# {'banana', 'orange', 'cherry', 'apple'}

# %%
fruits={"apple","banana","cherry"}
mylist=["kiwi","orange"]
fruits.update(mylist)
print(fruits)
# Out:
# {'cherry', 'banana', 'kiwi', 'orange', 'apple'}

# %%
fruits={"apple","banana","cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
fruits={"apple","banana","cherry"}
fruits.discard("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
fruits={"apple","banana","cherry"}
fruits.clear()
print(fruits)
# Out:
# set()

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1.union(set2)
print(set3) #union() function
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set1.update(set2)
print(set1) #update() function
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
x={"apple","banana","cherry"}
y={"google","microsoft","apple"}
z=x.intersection(y)
print(z) #intersection()
# Out:
# {'apple'}

# %%
x={"apple","banana","cherry"}
y={"google","microsoft","apple"}
x.intersection_update(y)
print(x) #intersection_update()
# Out:
# {'apple'}

# %%
x={"apple","banana","cherry"}
y={"google","microsoft","apple"}
z=x.symmetric_difference(y)
print(z) #symmetric_difference()
# Out:
# {'cherry', 'microsoft', 'banana', 'google'}

# %%
x={"apple","banana","cherry"}
y={"google","microsoft","apple"}
x.symmetric_difference_update(y)
print(x) #symmetric_difference_update()
# Out:
# {'google', 'banana', 'cherry', 'microsoft'}

# %% [markdown]
# # **6.FROZENSET**

# %%
nu=(1,2,3,4,5,6,7,8,9)
fnum=frozenset(nu)
print(fnum)
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 7, 8, 9})

# %% [markdown]
# # **7.DICTIONARIES**

# %%
cars={"brand":"BNW","model":"2nd series","year":"2004"}
print(cars)
# Out:
# {'brand': 'BNW', 'model': '2nd series', 'year': '2004'}

# %%
print(cars["model"]) # accesing an item
# Out:
# 2nd series

# %%
x=cars.get("model")
print(x)
# Out:
# 2nd series

# %%
x=cars.keys()
print(x)#keys method
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
x=cars.values()
print(x)# values method
# Out:
# dict_values(['BNW', '2nd series', '2004'])

# %%
cars={"brand":"Ford","model":"Mustang","year":"1964"}
x=cars.values()
print(x)
# Out:
# dict_values(['Ford', 'Mustang', '1964'])

# %%
cars["year"]=2020
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 2020])

# %%
cars["color"]="red"
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 2020, 'red'])

# %%
x=cars.items()
print(x)# items() method
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', '1964')])

# %%
cars.update({"year":2020})
print(cars) #update() function
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
cars={"brand":"Ford","model":"Mustang","year":"2020"}
cars.pop('year')
print(cars)#pop() function
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
cars={"brand":"Ford","model":"Mustang","year":"1964"}
cars.popitem()
print(cars)#popitem() method
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
del.cars["model"]
print(cars) #del keyword
# Out:
#   File "/tmp/ipython-input-3497982200.py", line 1
#     del.cars["model"]
#        ^
# SyntaxError: invalid syntax

# %%
cars.clear()
print(cars) #clear() method
# Out:
# {}

# %%
thisdict={"brand":"Ford","model":"Mustang","year":"1964"}
mydict=thisdict.copy()
print(mydict) #copy() function
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': '1964'}

# %%
mydict=dict(thisdict)
print(mydict) #dict()
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': '1964'}

# %% [markdown]
# ### **Nested dictionaries**

# %%
friends={"child1":{"name":"arun","year":2000},"child2":{"name":"vignesh","year":2001},"child3":{"name":"arya","year":2018}}
print(friends)
# Out:
# {'child1': {'name': 'arun', 'year': 2000}, 'child2': {'name': 'vignesh', 'year': 2001}, 'child3': {'name': 'arya', 'year': 2018}}

# %%
child1={"name":"arun","year":2000}
child2={"name":"vignesh","year":2001}
child3={"name":"arya","year":2018}
friends={"child1":child1,"child2":child2,"child3":child3}
print(friends)
# Out:
# {'child1': {'name': 'arun', 'year': 2000}, 'child2': {'name': 'vignesh', 'year': 2001}, 'child3': {'name': 'arya', 'year': 2018}}

# %% [markdown]
# # **CONDITIONAL STATEMENTS**

# %% [markdown]
# ## **IF STATEMENTS**

# %%
a=33
b=200
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a=33
b=200
if b>a:
print("b is greater than a") #indentation
# Out:
#   File "/tmp/ipython-input-2764493827.py", line 4
#     print("b is greater than a")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
a=33
b=33
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal") # elif
# Out:
# a and b are equal

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b") # else
# Out:
# a is greater than b

# %%
a=2
b=330
print("A") if a>b else print("B") # shorthand if
# Out:
# B

# %%
a=330
b=330
print("A") if a>b else print("=") if a==b else print("B") #shorthand if
# Out:
# =

# %% [markdown]
# ### **logical operators in if statements**

# %% [markdown]
# ### **1.and**

# %%
a=200
b=33
c=500
if a>b and c>a:
  print("both conditions are true")
# Out:
# both conditions are true

# %% [markdown]
# ### **2.or**

# %%
a=200
b=33
c=500
if a>b or a>c:
  print("atleast one of the conditions is true")
# Out:
# atleast one of the conditions is true

# %% [markdown]
# ### **nested if**

# %%
x=41
if x>10:
  print("Above ten")
  if x>20:
    print("and also above 20")
else:
  print("but not above 20")
# Out:
# Above ten
# and also above 20

# %% [markdown]
# ### **pass statement**

# %%
a=33
b=200
if b>a:
  pass

# %% [markdown]
# ## **LOOPING STATEMENTS**

# %% [markdown]
# ## **1.WHILE LOOP**

# %%
a=[1,2,3,4]
while a:
  print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
I=0
while I<4:
  I+=1
  print(I) #incrementation
# Out:
# 1
# 2
# 3
# 4

# %%
I=10
while I>2:
  I-=1
  print(I) #decrementation
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %% [markdown]
# ### **control statements**

# %% [markdown]
# ### **1.continue**

# %%
I=0
while I<4:
  I+=1
  print(I)
  continue
# Out:
# 1
# 2
# 3
# 4

# %%
i=0
a='loops in python'
while i<len(a):
  if a[i]=='e' or a[i]=='s':
    i+=1
    continue
  print('Current Letter:',a[i])
  i+=1
# Out:
# Current Letter: l
# Current Letter: o
# Current Letter: o
# Current Letter: p
# Current Letter:
# Current Letter: i
# Current Letter: n
# Current Letter:
# Current Letter: p
# Current Letter: y
# Current Letter: t
# Current Letter: h
# Current Letter: o
# Current Letter: n

# %% [markdown]
# ### **2.break**

# %%
I=0
while I<4:
  I+=1
  print(I)
  break
# Out:
# 1

# %%
i=0
a='loops in python'
while i<len(a):
  if a[i]=='p' or a[i]=='h':
    i+=1
    break
  print('Current Letter:',a[i])
  i+=1
# Out:
# Current Letter: l
# Current Letter: o
# Current Letter: o

# %% [markdown]
# ### **3.pass**

# %%
a='loop in python'
i=0
while i<len(a):
  i+=1
  pass
  print('value of i:',i)
# Out:
# value of i: 1
# value of i: 2
# value of i: 3
# value of i: 4
# value of i: 5
# value of i: 6
# value of i: 7
# value of i: 8
# value of i: 9
# value of i: 10
# value of i: 11
# value of i: 12
# value of i: 13
# value of i: 14

# %% [markdown]
# ## **2.WHILE-ELSE LOOP**

# %%
i=0
while i<4:
  i+=1
  print(i)
else:
  print("No Break\n")
# Out:
# 1
# 2
# 3
# 4
# No Break

# %%
i=0
while i<4:
  i+=1
  print(i)
  break
else:
   print("No Break")
# Out:
# 1

# %% [markdown]
# ##**3.FOR LOOPS**

# %%
print("List Iteration")
l=["hello","for","python"]
for i in l:
  print(i)
# Out:
# List Iteration
# hello
# for
# python

# %%
print("\nTuple Iteration")
t=("hello","for","python")
for i in t:
  print(i)
# Out:
# Tuple Iteration
# hello
# for
# python

# %% [markdown]
# ### **loop control statements**

# %% [markdown]
# ### **1.continue**

# %%
for x in 'python developer':
  if x=='e' or x=='o':
    continue
  print('Current Letter:',x)
# Out:
# Current Letter: p
# Current Letter: y
# Current Letter: t
# Current Letter: h
# Current Letter: n
# Current Letter:
# Current Letter: d
# Current Letter: v
# Current Letter: l
# Current Letter: p
# Current Letter: r

# %% [markdown]
# ### **2.break**

# %%
for x in 'python developer':
  if x=='o' or x=='e':
    break
  print('Current Letter:',x)
# Out:
# Current Letter: p
# Current Letter: y
# Current Letter: t
# Current Letter: h

# %% [markdown]
# ### **3.pass**

# %%
for x in 'python developer':
  pass
print("last letter:",x)
# Out:
# last letter: r

# %% [markdown]
# ## **RANGE() FUNCTION**

# %%
for i in range(10):
  print(i,end="")
# Out:
# 0123456789

# %%
for i in range(0,10):
  print(i,end="")
# Out:
# 0123456789

# %%
for i in range(1,10):
 print(i,end="")
# Out:
# 123456789

# %%
for i in range(4,10):
 print(i,end="")
# Out:
# 456789

# %%
for i in range(1,7,9):
 print(i,end="")
# Out:
# 1

# %%
l=[10,20,30,40]
for i in range(len(l)):
  print(l[i],end="")
# Out:
# 10203040

# %%
sum=0
for i in range(1,11):
  sum=sum+i
print("sum of first 10 natural numbers:",sum)
# Out:
# sum of first 10 natural numbers: 55

# %%
for i in range(0,11,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(0,11):
  if i == 3:
    pass
  elif i == 5:
    continue
  elif i == 7:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6

# %% [markdown]
# ## **4.FOR-ELSE LOOP**

# %%
for i in range(1,4):
  print(i)
else:
  print("No Break\n")
# Out:
# 1
# 2
# 3
# No Break

# %%
for i in range(1,4):
  print(i)
  break
else:
  print("No Break")
# Out:
# 1

# %% [markdown]
# ## **5.NESTED LOOP**

# %%
adj=["red","big","tasty"]
fruits=["apple","banana","cherry"]
for x in adj:
  for y in fruits:
    print(x,y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %% [markdown]
# # **PYTHON FUNCTIONS**

# %% [markdown]
# ## **calling a function**

# %%
def hello():
  print("Welcome to ipcs")
hello()
# Out:
# Welcome to ipcs

# %% [markdown]
# ## **arguments of a function**

# %%
def evenorodd(x):#x-argument
  if (x%2==0):
    print("even")
  else:
    print("odd")
evenorodd(25)#fun calling
# Out:
# odd

# %% [markdown]
# **GRADE PROGRAM**

# %%
def Grade(x):
  if x>=90:
    print("Grade:A")
  elif x>=80:
    print("Grade:B")
  elif x>=70:
    print("Grade:C")
  elif x>=60:
    print("Grade:D")
  else:
    print("Grade:E")
Grade(56)
Grade(65)
Grade(98)
# Out:
# Grade:E
# Grade:D
# Grade:A

# %% [markdown]
# **CALCULATOR PROGRAM**

# %%
def myFun(a,b,c):
  if c=="+":
    print(a+b)
  elif c=="-":
    print(a-b)
  elif c=="*":
    print(a*b)
  elif c=="%":
    print(a%b)
  elif c=="/":
    print(a/b)
  else:
    print("invalid operator")
myFun(10,20,"+")
myFun(56,89,"*")
myFun(45,5,"%")
myFun(56,8,"/")
# Out:
# 30
# 4984
# 0
# 7.0

# %% [markdown]
# ## **types of arguments**

# %% [markdown]
# ### **1.default argument**

# %%
def myFun(x,y=50):
  print("x:",x)
  print("y:",y)
myFun(10)
# Out:
# x: 10
# y: 50

# %% [markdown]
# ### **2.key word arguments**

# %%
def student(firstname,lastname):
  print(firstname,lastname)

student(firstname='python',lastname='functions')
student(lastname='hello',firstname='programmers')
# Out:
# python functions
# programmers hello

# %% [markdown]
# ### **3.Arbitrary arguments**

# %%
def my_function(*kids):
  print("The youngest child is "+kids[2])
my_function("Emil","Tobias","Linus")
# Out:
# The youngest child is Linus

# %%
def myfunction(*argv):
  for x in argv:
    print(x)
myfunction("Hello","Welcome","to","ipcs")
# Out:
# Hello
# Welcome
# to
# ipcs

# %% [markdown]
# ### **4.Arbitrary key word arguments**

# %%
def my_function(**student):
  print("His first name is "+student["fname"])
my_function(fname="Vignesh",lname="s")
# Out:
# His first name is Vignesh

# %%
def myFun(**kwargs):
 for key,value in kwargs.items():
  print("%s==%s"%(key,value))
myFun(first='welcome',mid='for',last='course')
# Out:
# first==welcome
# mid==for
# last==course

# %% [markdown]
# ## **default parameter value**

# %%
def my_function(country="Norway"):
  print('I am from '+country)
my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %% [markdown]
# ## **passing a list as an argument**

# %%
def my_function(xyz):
  for x in xyz:
    print(x)
fruits=["apple","banana","cherry"]
my_function(fruits)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## **RETURN VALUES**

# %%
def square_value(num):
  return num**2
print(square_value(2))
print(square_value(-4))
# Out:
# 4
# 16

# %%
def myfunction(x):
  x[0]=30
lst=[9,11,13,14,15]
myfunction(lst)
print(lst)
# Out:
# [30, 11, 13, 14, 15]

# %% [markdown]
# ## **function within functions**

# %%
def f1():
  s='I love python'
  def f2():
    print(s)
  f2()
f1()
# Out:
# I love python

# %% [markdown]
# # **python lambda**

# %%
string="hello python"
print(lambda string:string)
# Out:
# <function <lambda> at 0x791dc26aeca0>

# %%
x="hello python"
(lambda x:print(x))(x)
# Out:
# hello python

# %%
def cube(y):
  return y*y*y;
g=lambda x:x*x*x
print(g(7))
print(cube(5))
# Out:
# 343
# 125

# %%
def power(n):
  return lambda a: a**n
base=power(2)
print("Now power is set to 2")
print("6 power of 2 =",base(6))
base=power(5)
print("Now power is set to 5")
print("8 power of 5 =",base(8))
# Out:
# Now power is set to 2
# 6 power of 2 = 36
# Now power is set to 5
# 8 power of 5 = 32768

# %%
a=[100,2,8,60,5,4,3,31,10,11]
filtered=filter(lambda x: x%2==0 , a)
print(list(filtered))  # filter function filter()

maped=map(lambda x: x%2==0 , a)  #map()
print(list(maped))
# Out:
# [100, 2, 8, 60, 4, 10]
# [True, True, True, True, False, True, False, False, True, False]

# %% [markdown]
# # **global and local variables**

# %%
def myfunction():
  print(s)
s="i love python"
myfunction()
# Out:
# i love python

# %%
def myfunction():
  s="Me too."
  print(s)

s="i love python"
myfunction()
print(s)
# Out:
# Me too.
# i love python

# %%
a=1
def f():
  print('inside f():',a)
def g():
  a=2
  print('inside g():',a)
def h():
  global a
  a=3
  print('inside h():',a)


print('global:',a)
f()
print('golbal',a)
g()
print('golbal',a)
h()
print('golbal',a)
# Out:
# global: 1
# inside f(): 1
# golbal 1
# inside g(): 2
# golbal 1
# inside h(): 3
# golbal 3

# %% [markdown]
# # **first class functions in python**

# %% [markdown]
# ## **1.functions are objects**

# %%
def shout(text):
  return text.upper()
print(shout('Hello'))
yell=shout #object or instance
print(yell('Hello'))
# Out:
# HELLO
# HELLO

# %% [markdown]
# ## **2.functions can be passed as arguments to other functions**

# %%
def shout(text):
  return text.upper()
def whisper(text):
  return text.lower()
def greet(func):
  greeting=func("""Hi,I am created by a function passed as an argument.""")
  print(greeting)

greet(shout)
greet(whisper)
# Out:
# HI,I AM CREATED BY A FUNCTION PASSED AS AN ARGUMENT.
# hi,i am created by a function passed as an argument.

# %% [markdown]
# ## **3.functions can return another function**

# %%
def create_adder(x):
  def adder(y):
    return x+y
  return adder
add_15=create_adder(15)
print(add_15(10))
# Out:
# 25

# %% [markdown]
# # **RECURSIVE FUNCTIONS**

# %%
def calc_factorial(x):
  if x==1:
    return 1
  else:
    return(x*calc_factorial(x-1))
num=4
print("The factorial of",num,"is",calc_factorial(num))
# Out:
# The factorial of 4 is 24

# %% [markdown]
# # **modules and packages**

# %%
visual studio code

# %% [markdown]
# # **OOPS**

# %% [markdown]
# # **CLASS AND OBJECT**

# %%
class phone: #making phone class

  def make_call(self): #self is parameter
    print("let's make an phone call")

  def play_game(self): #method
    print("Let's play a game")

p1=phone()#make an object

# %%
p1.make_call()
# Out:
# let's make an phone call

# %%
p1.play_game()
# Out:
# Let's play a game

# %% [markdown]
# ## **adding parameter to the class**

# %%
class phone:

  def make_call(self):
    print("let's make an phone call")

  def play_game(self):
    print("Let's play a game")

  def set_color(self,color): #adding new parameter and create a new function
    self.color=color

  def set_cost(self,cost):
    self.cost=cost

  def show_color(self):
    return self.color

  def show_cost(self):
    return self.cost
p2=phone() #make an another object

# %%
p2.set_color('blue')

# %%
p2.set_cost(5000)

# %%
p2.show_color()
# Out:
# 'blue'

# %%
p2.show_cost()
# Out:
# 5000

# %% [markdown]
# ## **creating a class with constructor**

# %%
class Employee:

   def __init__(self,name,age,salary,gender): #__init__ method is an constructor

     self.name = name
     self.age = age
     self.salary = salary
     self.gender = gender


   def employee_details(self):
     print("Name of employee is ",self.name)
     print("Age of employee is ",self.age)
     print("Salary of employee is ",self.salary)
     print("Gender of employee is ",self.gender)

# %%
e1=Employee("Sam",32,85000,"Male")

# %%
e1.employee_details()
# Out:
# Name of employee is  Sam
# Age of employee is  32
# Salary of employee is  85000
# Gender of employee is  Male

# %% [markdown]
# ## **class**

# %%
class character:

  def __init__(self,health,damage,power):
    self.health = health
    self.damage = damage
    self.power = power

ninja = character(100,30,90)
warrior = character(200,40,95)
print("Power of ninja: ",ninja.power)
print("Power of ninja: ",ninja.health)
# Out:
# Power of ninja:  90
# Power of ninja:  100

# %%
class character:

    def __init__(self,health,damage,power):
      self.health = health
      self.damage = damage
      self.power = power

    def double(self):
      self.power=self.power*2
      self.damage=self.damage*3
ninja = character(100,30,90)
warrior = character(200,40,95)
print("Power of ninja: ",ninja.power)
print("Power of ninja: ",ninja.health)
ninja.double()
print("After doubling the power")
print("Power of ninja: ",ninja.power)
print("damage of ninja: ",ninja.damage)
# Out:
# Power of ninja:  90
# Power of ninja:  100
# After doubling the power
# Power of ninja:  180
# damage of ninja:  90

# %%
class character:

    def __init__(self,name,health,damage,power):
      self.name=name
      self.health = health
      self.damage = damage
      self.power = power

    def hai(self):
      print("Hello I am ",self.name)

    def is_alive(self):
      if self.health<=0:
        print(self.name,"is Dead!")
      else:
        print(self.name,"is Alive!")


    def player_details(self):
      print("....."*5)
      print("Name of player is: ",self.name)
      print("Health of player is: ",self.health)
      print("Damage of player is: ",self.damage)
      print("Power of player is: ",self.power)
      print()

ninja = character("Ninja",100,30,90)
warrior = character("Warrior",200,40,95)


ninja.hai()
ninja.health=0
print("Health of ninja:",ninja.health)
ninja.is_alive()
warrior.is_alive()

warrior.player_details()
ninja.player_details()
# Out:
# Hello I am  Ninja
# Health of ninja: 0
# Ninja is Dead!
# Warrior is Alive!
# .........................
# Name of player is:  Warrior
# Health of player is:  200
# Damage of player is:  40
# Power of player is:  95
#
# .........................
# Name of player is:  Ninja
# Health of player is:  0
# Damage of player is:  30
# Power of player is:  90

# %% [markdown]
# ## **class attributes**

# %%
class student:

  school='abc school'

  def __init__(self,name,age,roll_number):
    self.name = name #instance attributes
    self.age = age
    self.roll_number = roll_number

  def details(self): #method
     print(f"{self.name} is : {self.age} year old is studying at : {self.school} and roll number is {self.roll_number}")

student1= student("Anshif",21,3)
student2= student("Sinan",20,9)
print(student1.school)

student.school="Learn Logic AI" #updating class attributes

student1.details()
# Out:
# abc school
# Anshif is : 21 year old is studying at : Learn Logic AI and roll number is 3

# %% [markdown]
# ## del operator

# %%
class student:

  school='abc school'

  def __init__(self,name,age,roll_number):
    self.name = name #instance attributes
    self.age = age
    self.roll_number = roll_number

  def details(self): #method
     print(f"{self.name} is : {self.age} year old is studying at : {self.school} and roll number is {self.roll_number}")

student1= student("Anshif",21,3)
student2= student("Sinan",20,9)
print(student1.school)
del student1.name
print(student1.name) #it show an error
# Out:
# abc school
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3309479332.py in <cell line: 0>()
#      15 print(student1.school)
#      16 del student1.name
# ---> 17 print(student1.name)
#
# AttributeError: 'student' object has no attribute 'name'

# %% [markdown]
# ## **python built-in class function**

# %%
class student:

  school='abc school'

  def __init__(self,name,age,roll_number):
    self.name = name #instance attributes
    self.age = age
    self.roll_number = roll_number

  def details(self): #method
     print(f"{self.name} is : {self.age} year old is studying at : {self.school} and roll number is {self.roll_number}")

student1= student("Anshif",21,3)
student2= student("Sinan",20,9)
print(getattr(student1,"name"))

setattr(student1,"age",23)
print(student1.age)

print(hasattr(student1,"id"))

delattr(student1,"age")
# Out:
# Anshif
# 23
# False

# %%
class dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def bark(self):
    print(f"{self.name} says: Bow! Bow!")

  def intriduce(self):
    print(f"My name is {self.name} and I am {self.age} years old.")

  def sit(self):
    print(f"{self.name} is now sitting.")

  def fetch(self,item):
    print(f"{self.name} is fetching the {item}")


dog1=dog("Mubashir",21)
dog2=dog("Jaseem",19)
dog1.bark()
dog2.bark()
dog1.sit()
dog1.fetch("Alpham mandhi")
dog2.fetch("stick")
# Out:
# Mubashir says: Bow! Bow!
# Jaseem says: Bow! Bow!
# Mubashir is now sitting.
# Mubashir is fetching the Alpham mandhi
# Jaseem is fetching the stick

# %% [markdown]
# # **INHERITANCE IN OOP**

# %% [markdown]
# ## **1.single inheritance**
# (single parent and single child)

# %%
class Animal: # parent class
  def speak(self):
    print("Animal speaking")

class Dog(Animal): # child class(inheritance)
  def bark(self):
    print("Dog barking")

d=Dog()
d.bark()
d.speak() #we can call speak because Dog is child of Animal

a=Animal()
a.speak() #here we cannot call bark because bark attribute not in Animal object
# Out:
# Dog barking
# Animal speaking
# Animal speaking

# %%
class vehicle:
  def start(self):
    print("vehicle is starting..")
  def stop(self):
    print("vehicle is stopping..")

class car(vehicle):
  def drive(self):
    print("car is being driven")


my_car=car()
my_car.start()
my_car.drive()
my_car.stop()
# Out:
# vehicle is starting..
# car is being driven
# vehicle is stopping..

# %% [markdown]
# ## **2.multilevel inheritance**
# (parent,child,grand child)

# %%
class Animal: # parent class
  def speak(self):
    print("Animal speaking")

class Dog(Animal): # child class
  def bark(self):
    print("Dog barking")

class Dogchild(Dog): # grand child
  def eat(self):
    print("Eating bread....")


d=Dog()
d.bark()
d.speak() # not take eat because Dog has no attribute eat.

print()

d1=Dogchild()
d1.bark()
d1.speak()
d1.eat()
# Out:
# Dog barking
# Animal speaking
#
# Dog barking
# Animal speaking
# Eating bread....

# %% [markdown]
# ## **3.hierarchial inheritance**
# (one parent,two child)

# %%
class shape: # parent class
  def info(self):
    print("Shapes have dimensions...")

class circle(shape): # this is child of shape
  def draw(self):
    print("Drawing a circle...")

class rectangle(shape): # this is also child of shape
  def draw(self):
    print("Drawing a rectangle...")

c=circle()
r=rectangle()
c.info()
c.draw()
print()
r.info()
r.draw()
# Out:
# Shapes have dimensions...
# Drawing a circle...
#
# Shapes have dimensions...
# Drawing a rectangle...

# %%
class person: # parent class
  def introduce(self):
    print("I am a person...")

class Teacher(person): # child of person
  def teach(self):
    print("I teach students...")

class Student(person): # also child of person
  def study(self):
    print("I study subjects...")

teacher=Teacher()
student=Student()

teacher.introduce()
teacher.teach()

print()

student.introduce()
student.study()
# Out:
# I am a person...
# I teach students...
#
# I am a person...
# I study subjects...

# %% [markdown]
# ## **4.multiple inheritance**
# (two parent , one child)

# %%
class Calculation1: # parent class
  def summation(self,a,b):
    print(a+b)

class Calculation2: # another parent class
  def multiplication(self,a,b):
    print(a*b)

class Derived(Calculation1,Calculation2): # child from that both parent classes
  def divide(self,a,b):
    print(a/b)


d=Derived()
d.summation(10,20)
d.multiplication(10,20)
d.divide(10,20)
# Out:
# 30
# 200
# 0.5

# %% [markdown]
# ## **HYBRID INHERITANCE**

# %%
class person:
  def show(self):
    print("I am a person")
class teacher(person):
  def teach(self):
    print("I teach students")

class staff:
  def manage(self):
    print("I manage school activities")



class principal(teacher,staff):
  def oversea(self):
    print("I oversea the entire school ")


principal=principal()
principal.show()
principal.teach()
principal.manage()
principal.oversea()
# Out:
# I am a person
# I teach students
# I manage school activities
# I oversea the entire school

# %% [markdown]
# ## **SUPER() METHOD**

# %%
class parent:
  def greet1(self):
    print("Hello from parent..")

class child(parent):
  def greet2(self):
    super().greet1()
    print("Hello from child..")

child=child()
child.greet2()
# Out:
# Hello from parent..
# Hello from child..

# %%
class parent:
  def __init__(self,name):
    self.name=name
    print("parent constructor called..")

class child(parent):
  def __init__(self,name,age):
    super().__init__(name)
    self.age=age
    print("child constructor called..")

child=child("Anshif",21)
# Out:
# parent constructor called..
# child constructor called..

# %% [markdown]
# # **POLYMORPHISM**

# %% [markdown]
# ## **1.METHOD OVERRIDING**

# %%
class A:
  def show(self):
    print("class A")

class B(A):
  def show(self):
    print("class B")

class C(B):
  def show(self):
    print("class C")

obj=C()
obj.show()
# Out:
# class C

# %%
class A:
  def show(self):
    print("class A")

class B(A):
  def show(self):
    super().show()
    print("class B")

class C(B):
  def show(self):
    super().show()
    print("class C")

obj=C()
obj.show() # use super() method we get all classes
# Out:
# class A
# class B
# class C

# %%
class Animal:
  def speak(self):
    print("Animal is making sound")

class Dog(Animal):
  def speak(self):
    print("Dog barks")

class Cat(Animal):
  def speak(self):
    print("Cat meows")

dog=Dog()
cat=Cat()

dog.speak()
cat.speak()
# Out:
# Dog barks
# Cat meows

# %% [markdown]
# ## **2.METHOD OVERLOADING**

# %% [markdown]
# ### **1.default arguments**
# (give different values to parameters)

# %%
class calculator:
  def add(self,a,b=0,c=0):
    print(a+b+c)

calc=calculator()

calc.add(5)
calc.add(5,10)
calc.add(5,10,20)
# Out:
# 5
# 15
# 35

# %% [markdown]
# ### **2.variable length arguments**
# (methods to accept different number of arguments)

# %% [markdown]
# * positinal arguments(args)

# %%
class mathoperations:
  def add(self,*numbers):
    total=sum(numbers)
    print(f"sum:{total}")

math=mathoperations()

#call the method with n number of arguments using (*args)
math.add(5)
math.add(5,10)
math.add(1,2,3,4)
# Out:
# sum:5
# sum:15
# sum:10

# %% [markdown]
# *kerword arguments(kwargs)

# %%
class Greeting:
  def say_hello(self,**kwargs):
    print(f"Hello {kwargs['name']}!")
    print(f"You are {kwargs['age']} years old!")
    print(f"You are from {kwargs['city']}!")

g=Greeting()
g.say_hello(name="Anshif",age=21,city="Puthanathani")
# Out:
# Hello Anshif!
# You are 21 years old!
# You are from Puthanathani!

# %% [markdown]
# # **ENCAPSULATION**

# %%
class company:
  def __init__(self,company_name,company_id):
    self.__company_name = company_name # here company_name is a private member because double underscore
    self._company_id = company_id # company_id is a protected member because single underscore

c1=company("TCS",91)
print(c1._company_id) # we cannot print company_name because it is a protected member
# Out:
# 91

# %%
class company:
  def __init__(self,company_name,company_id):
    self.__company_name = company_name
    self._company_id = company_id

  def get_company_name(self):
    print(self.__company_name)

c1=company("TCS",91)
c1.get_company_name()
# Out:
# TCS

# %%
class bankaccount:
  def __init__(self,account_number,balance):
    self.__account_number = account_number
    self.__balance = balance
  def deposit(self,amount):
    if amount > 0 :
      self.__balance += amount
      print(f"Deposited {amount}. New balance: {self.__balance}")
    else:
      print("Invalid deposit error")

  def get_balance(self):
    return self.__balance

account = bankaccount("12345" , 1000)
account.deposit(500)
print(account.get_balance())
# Out:
# Deposited 500. New balance: 1500
# 1500

# %%
class bankaccount:
  def __init__(self,account_number,balance):
    self.__account_number = account_number
    self.__balance = balance
  def withdraw(self,amount):
    if  amount <= 0 :
      print("enter proper amount")
    elif amount < self.__balance:
      self.__balance -= amount
      print(f"withdraw { amount }. New balance : {self.__balance}")
    elif amount >= self.__balance:
      print("insufficient balance")
    else:
      print("invalid")

  def get_balance(self):
    return self.__balance


account = bankaccount("12345" , 1000)
account.withdraw(600)
print(account.get_balance())
# Out:
# withdraw 600. New balance : 400
# 400

# %% [markdown]
# # **ABSTRACTION**

# %% [markdown]
# (from abc , import ABC , abstract method)

# %%
from abc import ABC , abstractmethod

class vehicle(ABC): # abstract class

  @abstractmethod
  def start_engine(self):
    pass

  @abstractmethod
  def stop_engine(self):
    pass

v=vehicle() # result will be error.we create child class to avoid error.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-772567600.py in <cell line: 0>()
#      11     pass
#      12
# ---> 13 v=vehicle()
#
# TypeError: Can't instantiate abstract class vehicle without an implementation for abstract methods 'start_engine', 'stop_engine'

# %%
from abc import ABC , abstractmethod

class vehicle(ABC): # abstract class

  @abstractmethod
  def start_engine(self):
    pass

  @abstractmethod
  def stop_engine(self):
    pass

class car(vehicle): # child class

  def start_engine(self): # we create same function as parent class otherwise we get error
   print("car engine started")

  def stop_engine(self):  # we create same function as parent class otherwise we get error
    print("car engine stopped")

car=car()
car.start_engine()
car.stop_engine()
# Out:
# car engine started
# car engine stopped

# %%
from abc import ABC, abstractmethod

class shape(ABC):
  @abstractmethod
  def calculate_area(self):
    pass

class Circle(shape):

  def __init__(self,radius):
    self.radius=radius

  def calculate_area(self):
    print(f"circle area is : {3.14 * (self.radius)**2}")


class Rectangle(shape):

  def __init__(self,width,height):
    self.width=width
    self.height=height

  def calculate_area(self):
    print(f"Rectangle area is : {self.width * self.height}")


cir=Circle(10)
rect=Rectangle(5,10)

cir.calculate_area()
print()
rect.calculate_area()
# Out:
# circle area is : 314.0
#
# Rectangle area is : 50

# %% [markdown]
# # **CLASS METHOD**

# %%
class car: #class variable
  wheels=4

  def __init__(self,brand,model):
    self.brand=brand
    self.model=model

  @classmethod
  def change_wheels(cls,new_wheels):
    cls.wheels=new_wheels
    print(f"The number of wheels has been updated to {cls.wheels}.")

car1=car("Toyota","Etios") # create instance of car

# call the class method
car.change_wheels(6)

print()

print(f"car variable updated to : {car1.wheels}") #class variable "wheels" is now changed to all instances
# Out:
# The number of wheels has been updated to 6.
#
# car variable updated to : 6

# %% [markdown]
# # **ITERATOR**

# %%
mytuple=("apple","banana","cherry")
myit=iter(mytuple)

# %%
print(next(myit))
# Out:
# apple

# %%
print(next(myit))
# Out:
# banana

# %%
print(next(myit))
# Out:
# cherry

# %%
mystring="banana"
myit=iter(mystring)

# %%
print(next(myit))
# Out:
# b

# %%
print(next(myit))
# Out:
# a

# %%
print(next(myit))
# Out:
# n

# %%
print(next(myit))
# Out:
# a

# %%
print(next(myit))
# Out:
# n

# %%
print(next(myit))
# Out:
# a

# %% [markdown]
# ## **looping through an iterator**

# %%
mytuple=("apple","banana","cherry")
for x in mytuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
class MyNumbers:
  def __iter__(self):
    self.a = 1
    return self

  def __next__(self):
    x = self.a
    self.a += 1
    return x

myclass = MyNumbers()
myiter = iter(myclass)

# %%
print(next(myiter))
# Out:
# 1

# %%
print(next(myiter))
# Out:
# 2

# %%
print(next(myiter))
print(next(myiter))
# Out:
# 3
# 4

# %% [markdown]
# # **GENERATORS**

# %%
def greeting():
  print('Hi!')
  yield 1
  print('How are you?')
  yield 2
  print('Are you there?')
  yield 3

messenger = greeting()

result = next(messenger)
print(result)
# Out:
# Hi!
# 1

# %%
result = next(messenger)
print(result)
# Out:
# How are you?
# 2

# %%
result = next(messenger)
print(result)
# Out:
# Are you there?
# 3

# %% [markdown]
# # **FILE HANDLING**

# %%
file = open("newfile.txt", "x")
file.write("This file was created using 'x' mode.")
file.close()

# %%
file = open("newfile.txt", "r")
content = file.read()
print(content)
# Out:
# This file was created using 'x' mode.

# %%
file = open("newfile.txt", "w")
file.write("Hello, world!\n")
file.write("This is Python.")
file.close()

# %%
file = open("newfile.txt", "r")
content = file.read()
print(content)
# Out:
# Hello, world!
# This is Python.

# %%
file = open("newfile.txt", "a")
file.write("\nAppended line.")
file.close()

# %%
file = open("newfile.txt", "r")
content = file.read()
print(content)
# Out:
# Hello, world!
# This is Python.
# Appended line.

# %% [markdown]
# above we use open then we close manually.next we do withopen ,not close manually

# %% [markdown]
# 1. Create a file using 'x' mode

# %%
with open("demo.txt","x") as f:
  f.write("This file was created using 'x' mode.\n")

# %% [markdown]
# 2. Read the file using 'r' mode

# %%
with open("demo.txt","r") as f:
  content = f.read()
  print("[After 'x' mode creation]")
  print(content)
# Out:
# [After 'x' mode creation]
# This file was created using 'x' mode.

# %% [markdown]
# 3. Write to the file using 'w' mode (this will overwrite the file)

# %%
with open("demo.txt","w") as f:
  f.write("This content overwrites the file using 'w' mode")

# %% [markdown]
# 4. Read the file again

# %%
with open("demo.txt","r") as f:
  content = f.read()
  print("[After 'w' mode write]")
  print(content)
# Out:
# [After 'w' mode write]
# This content overwrites the file using 'w' mode

# %% [markdown]
# 5. Append to the file using 'a' mode

# %%
with open("demo.txt","a") as f:
  f.write("This line is added using 'a' mode.\n")

# %% [markdown]
# 6. Final read

# %%
with open("demo.txt","r") as f:
  content = f.read()
  print("[final read after append]")
  print(content)
# Out:
# [final read after append]
# This content overwrites the file using 'w' modeThis line is added using 'a' mode.This line is added using 'a' mode.
# This line is added using 'a' mode.

# %% [markdown]
# # **EXCEPTION HANDLING**

# %% [markdown]
# ## **1.syntax error**

# %%
if 5>3
  print("This will cause a syntax error")
# Out:
#   File "/tmp/ipython-input-416297824.py", line 1
#     if 5>3
#           ^
# SyntaxError: expected ':'

# %% [markdown]
# ## **2.runtime errors**

# %%
x=1/0
print(x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-223042854.py in <cell line: 0>()
# ----> 1 x=1/0
#       2 print(x)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## **3.logical errors**

# %%
length = 5
width = 10
area = length  + width #should be length*width
print("Area:",area)
# here program run bot result is wrong . this is logical error
# Out:
# Area: 15

# %%
try:
    num = int(input("Enter the number: "))
    result = 10/num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Please enter a valid number!")
else:
    print("Division successful! Result:" , result)
finally:
    print("This block always runs.")
# Out:
# Enter the number: 5
# Division successful! Result: 2.0
# This block always runs.

# %% [markdown]
# # **exceptions**

# %% [markdown]
# ## **try-except block**

# %%
try:
  x=int(input("Enter the number: "))
  y = 10/x
  print(y)
except ZeroDivisionError:
  print("cannot divide by zero")
# Out:
# Enter the number: 0
# cannot divide by zero

# %%
try:
  x=int(input("Enter the number: "))
  y = 10/x
  print(y)
except ZeroDivisionError as e:
  print(e)
# Out:
# Enter the number: 0
# division by zero

# %%
try:
  print(a) # here a is not defined
except:
  print("Error occured")   # use try-except block , error will not show.
# Out:
# Error occured

# %%
print(a)
print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2024701104.py in <cell line: 0>()
# ----> 1 print(a)
#       2 print("Hello World")
#
# NameError: name 'a' is not defined

# %%
try:
  print(a)
except:
  print("Error occured")
print("Hello World")
# Out:
# Error occured
# Hello World

# %% [markdown]
# ## **Else and finally block**

# %% [markdown]
# ## **Else block**

# %%
try:
  result = 10/2
except ZeroDivisionError:
  print("Error")
else:
  print("Result:" , result)
# Out:
# Result: 5.0

# %% [markdown]
# ## **finally block**

# %%
try:
  file_=open("data.txt","r")

except FileNotFoundError:
  print("File Not Found!")

finally:
  print("End of program")
# Out:
# File Not Found!
# End of program

# %%
import math
print(math.exp(1000)) # overflow error
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipython-input-790541606.py in <cell line: 0>()
#       1 import math
# ----> 2 print(math.exp(1000))
#
# OverflowError: math range error

# %%
obj = 42
obj.append(5) # attribute error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-418952538.py in <cell line: 0>()
#       1 obj = 42
# ----> 2 obj.append(5)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
data = {"name":"john"}
print(data[age]) # key error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2924017689.py in <cell line: 0>()
#       1 data = {"name":"john"}
# ----> 2 print(data[age])
#
# NameError: name 'age' is not defined

# %%
my_list = [1,2,3]
print(my_list[5]) # index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-209300591.py in <cell line: 0>()
#       1 my_list = [1,2,3]
# ----> 2 print(my_list[5])
#
# IndexError: list index out of range

# %%
print(int("hello")) # value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-148294692.py in <cell line: 0>()
# ----> 1 print(int("hello"))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
my_list =[1,2,3]
my_list.remove(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3468833774.py in <cell line: 0>()
#       1 my_list =[1,2,3]
# ----> 2 my_list.remove(5)
#
# ValueError: list.remove(x): x not in list

# %%
print("5"+5) # type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3543003934.py in <cell line: 0>()
# ----> 1 print("5"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
open("nonexistnt_file,.txt") # filenotfounderror
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-254438997.py in <cell line: 0>()
# ----> 1 open("nonexistnt_file,.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistnt_file,.txt'

# %%
try:
  open("nonexistnt_file,.txt")
except FileNotFoundError as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'nonexistnt_file,.txt'

# %% [markdown]
# ## **Raise exception**

# %%
age = int(input("Enter the age: "))

if age<0:
  raise ValueError("Age cannot be negative")

else:
  print(f"your age is {age}")

print("No try except")
# Out:
# Enter the age: -5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2963508233.py in <cell line: 0>()
#       2
#       3 if age<0:
# ----> 4   raise ValueError("Age cannot be negative")
#       5
#       6 else:
#
# ValueError: Age cannot be negative

# %%
try:
  age = int(input("Enter the age: "))

  if age<0:
    raise ValueError("Age cannot be negative")

  else:
    print(f"your age is {age}")

except ValueError as e:
  print(e)

print("try except finished")
# Out:
# Enter the age: -5
# Age cannot be negative
# try except finished

# %% [markdown]
# ## **custom exceptions**

# %%
class InvalidAgeException(Exception):
  pass

number = 18
try:
  input_num = int(input("Enter a number: "))

  if input_num < number:
    raise InvalidAgeException

  else:
    print("Eligible to Vote")

except InvalidAgeException:
  print("Exception occured : Invalid Age")
# Out:
# Enter a number: 16
# Exception occured : Invalid Age

# %% [markdown]
# # **THREADING**

# %% [markdown]
# ## **basic thread**

# %%
import threading

def task():
  print("Thread running")

thread = threading.Thread(target = task)

thread.start()

thread.join()
# Out:
# Thread running

# %% [markdown]
# ## **multiple threads**

# %%
import threading

def task1():
  print("Task 1")

def task2():
  print("Task 2")

t1 = threading.Thread(target = task1)
t2 = threading.Thread(target = task2)

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# Task 1
# Task 2

# %%
import threading

def print_numbers():
  for i in range(5):
    print(i)

thread = threading.Thread(target = print_numbers)

thread.start()

thread.join()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import threading
import time

def download_file(file):
  print(f"Downloading {file}...")
  time.sleep(2)
  print(f"{file} downloaded.")

files = ["file1.txt","file2.txt","file3.txt"]
threads = [threading.Thread(target = download_file,args=(f,))for f in files]

for t in threads:
 t.start()

for t in threads:
 t.join()
# Out:
# ...
# file1.txt downloaded.
# file2.txt downloaded.
# file3.txt downloaded.

# %% [markdown]
# ## **two threading**

# %%
import threading
import time

def chef_work():  # function for the chef's work(thread 1)
   for i in range(5): # chef prepares 5 dishes
       print(f"Chef: preparing dish {i+1}...")
       time.sleep(2) # time taken to prepare a dish
       if i == 2:  # Assistant starts washing utensils during the third dish
           print("Chef: calling Assistant to wash utensils.")
           time.sleep(1) # time taken to call the assistant
           assistant_thread = threading.Thread(target = assistant_work)
           assistant_thread.start()
           assistant_thread.join() # wait for the assistant to finish
           print("Chef: Assistant done.Resuming dish preparation.")
   print("Chef: All dishes are prepared.")


def assistant_work(): # function for assistant's work (thread 2)
    for j in range(3): # Assistant wah 3 utensils.
        print(f"  Assistant: washing utensil {j+1}...")
        time.sleep(2) # time taken to wash each utensil.
    print("  Assistant: All utensils are clean.")


print("Kitchen: Starting work.")
chef_thread = threading.Thread(target = chef_work)
chef_thread.start()
chef_thread.join()
print("Kitchen: All work completed.") # wait for the chef to complete their work.
# Out:
# Kitchen: Starting work.
# Chef: preparing dish 1...
# Chef: preparing dish 2...
# Chef: preparing dish 3...
# Chef: calling Assistant to wash utensils.
#   Assistant: washing utensil 1...
#   Assistant: washing utensil 2...
#   Assistant: washing utensil 3...
#   Assistant: All utensils are clean.
# Chef: Assistant done.Resuming dish preparation.
# Chef: preparing dish 4...
# Chef: preparing dish 5...
# Chef: All dishes are prepared.
# Kitchen: All work completed.

# %% [markdown]
# Qustion
# Write a Python program using threading to simulate music playback and lyrics downloading:
#
# Music playback runs in one thread for 5 seconds, printing a message each second. During the 3rd second, a separate thread starts to simulate downloading lyrics, which takes 3 seconds. Ensure the music playback waits for the lyrics to finish downloading before continuing.
#
# Output
#
# Music Player: Starting music playback. Music Player: Playing music... 1 seconds Music Player: Playing music... 2 seconds Music Player: Playing music... 3 seconds Music Player: Downloading lyrics in the background. Downloading lyrics... 1 seconds Downloading lyrics... 2 seconds Downloading lyrics... 3 seconds Lyrics download completed. Music Player: Lyrics downloaded. Music Player: Playing music... 4 seconds Music Player: Playing music... 5 seconds Music Player: Playback ended

# %%
import threading
import time

def music_player():
  for i in range(5):
    print(f"Music Player : Playing music... {i+1} seconds.")
    time.sleep(3)
    if i == 2 :
      print("Music player: Downloading lyrics in the background.")
      time.sleep(2)
      download_thread = threading.Thread(target = download_lyrics)
      download_thread.start()
      download_thread.join()
      print("Music player : Lyrics downloaded")


def download_lyrics():
  for j in range(3):
    print(f" Downloading lyrics...{j+1} seconds.")
    time.sleep(2)
  print("Lyrics downloaded completed.")


print("Music Player : Starting music playback.")
music_thread = threading.Thread(target = music_player)
music_thread.start()
music_thread.join()
print("Music player : Playback ended.")
# Out:
# Music Player : Starting music playback.
# Music Player : Playing music... 1 seconds.
# Music Player : Playing music... 2 seconds.
# Music Player : Playing music... 3 seconds.
# Music player: Downloading lyrics in the background.
# ...
# Lyrics downloaded completed.
# Music player : Lyrics downloaded
# Music Player : Playing music... 4 seconds.
# Music Player : Playing music... 5 seconds.
# Music player : Playback ended.

# %% [markdown]
# # **REGULAR EXPRESSIONS**

# %% [markdown]
# search the string to see if it starts with "The" and ends with "Spain":

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$",txt)
if x:
  print("YES! we have a match!")

else:
  print("No match!")
# Out:
# YES! we have a match!

# %% [markdown]
# findall() function
# print a list of all matches.

# %%
import re

txt = "The rain in Spain"
x = re.findall("ai",txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re

txt = "The rain in Spain"
x = re.findall("Portugal",txt)
print(x)

if x:
  print("YES, there is atleast one match.")
else:
  print("no match")
# Out:
# []
# no match

# %% [markdown]
# search for the first whitespace character for the string.

# %%
import re

txt = "The rain in Spain"
x = re.search("\s",txt)
print("The first whitespace character located in the position:", x.start())
# Out:
# The first whitespace character located in the position: 3
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1855367925.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s",txt)

# %%
import re

txt = "The rain in Spain"
x = re.search("Portugal",txt)
print(x)
# Out:
# None

# %% [markdown]
# split function():split at each whitespace character

# %%
import re

txt = "The rain in Spain"
x = re.split("\s",txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3772022889.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s",txt)

# %% [markdown]
# split the string only at the first occurence

# %%
import re

txt = "The rain in Spain"
x = re.split("\s",txt,1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-365587355.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s",txt,1)

# %% [markdown]
# sub function : replace every white space character with number 9

# %%
import re

txt = "The rain in Spain"
x = re.sub("\s","9",txt)
print(x)
# Out:
# The9rain9in9Spain
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1707037135.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s","9",txt)

# %% [markdown]
# replace the first 2 occurences

# %%
import re

txt = "The rain in Spain"
x = re.sub("\s","9",txt,2)
print(x)
# Out:
# The9rain9in Spain
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-4079580978.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s","9",txt,2)

# %% [markdown]
# match object

# %%
import re

txt = "The rain in Spain"
x = re.search("ai",txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+" , txt)
print(x.span())
# Out:
# (12, 17)

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+" , txt)
print(x.group())
# Out:
# Spain

# %%
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+" , txt)
print(x.string())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1609361261.py in <cell line: 0>()
#       3 txt = "The rain in Spain"
#       4 x = re.search(r"\bS\w+" , txt)
# ----> 5 print(x.string())
#
# TypeError: 'str' object is not callable
