# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# used to show data graphically

# %% [markdown]
# # **matplotlib pyplot**

# %% [markdown]
# lets draw a line in a diagram in a position (0,0) to (6,250):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# # **matplotlib plotting**

# %% [markdown]
# ## **plotting without line**

# %% [markdown]
# [use the parameter 'o' which means 'rings']

# %% [markdown]
# draw two points in the diagram , one at position (1,3) and one in position (8,10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# draw a line in a diagram from position (1,3) to (2,8) then to (6,1) and finally to position (8,10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ## **Default x points**

# %% [markdown]
# do not specify points on x axis..they will get the default values 0,1,2,3,..

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # **Matplotlib Markers**

# %% [markdown]
# mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker='o')
plt.show()

# %% [markdown]
# we can give *

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# ## **format strings fmt**

# %% [markdown]
# mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,'o:r')  # : means dotted line and 'r' means red color..
plt.show()

# %% [markdown]
# ## **marker size**(ms)

# %% [markdown]
# set the size of markers to 20:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker='o',ms=20)
plt.show()

# %% [markdown]
# ## **marker color(mec)**

# %% [markdown]
# set the edge color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker='o',ms=20,mec='r')
plt.show()

# %% [markdown]
# ## **marker face color(mfc)**

# %% [markdown]
# set markerfacecolor to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker='o',ms=20,mec='r',mfc='r')
plt.show()

# %% [markdown]
# # **matplotlib line**

# %% [markdown]
# ## **linestyle(ls)**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dashed')
plt.show()

# %% [markdown]
# ## **linecolor(c)**

# %% [markdown]
# set line color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,color='r')
plt.show()

# %% [markdown]
# ## **linewidth(lw)**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,linewidth='20.5')
plt.show()

# %% [markdown]
# ## **multiple lines**

# %% [markdown]
# we can add multiple lines by adding more plt.plot():

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# both x and y values:

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])

x2 = np.array([0,1,2,3])
y2 = np.array([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # **matplotlib labels and titles**

# %% [markdown]
# xlabel() and ylabel() :

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## **Create a title for a plot**

# %% [markdown]
# title() :

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## **set font properties for title and labels**

# %% [markdown]
# we can use fondict parameter in xlabel() , ylabel() and title():

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data",fontdict = font1)
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)


plt.plot(x,y)
plt.show()

# %% [markdown]
# ## **position the title**

# %% [markdown]
# loc parameter:,
# legal values- left,right,center:
# default value-center

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])


plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)
plt.show()

# %% [markdown]
# # **matplotlib adding grid lines**

# %% [markdown]
# grid() function:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])


plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")


plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# we can use axis parameter in the grid() function to specify which grid lines to specify:,legal values-x,y,both:,default value-both

# %% [markdown]
# Display only grid lines for the x axis...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])


plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")


plt.plot(x,y)
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ## **properties of grid**

# %% [markdown]
# grid(color='color',linestyle='linestyle',linewidth=number)

# %% [markdown]
# set the line properties of grid:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])


plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")


plt.plot(x,y)
plt.grid(color='green',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# # **matplotlib subplots**

# %% [markdown]
# subplots means more than one gragh in a single plot...
# use subplot() function.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)    # 1-no.of raws , 2-no.of columns , 1-first plot
plt.plot(x,y)

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,2)  # 1-raws , 2-columns,2-second plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## **The subplots() function**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## **Title**

# %% [markdown]
# you can add title on each plot using title() function:

# %% [markdown]
# 2 plots with titles:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# ## **Super Title**

# %% [markdown]
# you can add title to the entire figure using suptitle() function:

# %% [markdown]
# add a title for the entire figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # **Matplotlib Scatter**

# %% [markdown]
# to draw a scatter plot by using scatter() function..

# %% [markdown]
# A simple scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## **Compare plots**

# %% [markdown]
# Draw two plots in the same figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1 (13 numbers)
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

# plot 2 (15 numbers)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)

plt.show()

# %% [markdown]
# ## **Colors**

# %% [markdown]
# we can set your own color for each scatter plot with the color or c argument:

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1 (13 numbers)
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,color='hotpink')

# plot 2 (15 numbers)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,color='#88c999')

plt.show()

# %% [markdown]
# ## **Color Each Dot**

# %% [markdown]
# set our own colors of markers...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x,y,c=colors)
plt.show()

# %% [markdown]
# ## **ColorMap**

# %% [markdown]
# plt.colorbar():

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])

plt.scatter(x,y,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ## **Size**

# %% [markdown]
# you can change the size of the dots using s argument..

# %% [markdown]
# sets your own size for the markers..

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x,y,s=sizes)
plt.show()

# %% [markdown]
# ## **Alpha**

# %% [markdown]
# you can adjust the transparency of the dots with the alpha argument..

# %% [markdown]
# sets your own size for the markers..

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x,y,s=sizes,alpha=0.5)
plt.show()

# %% [markdown]
# ## **Combine Color Size And Alpha**

# %% [markdown]
# Create random arrays with 100 values for x points,y points ,colors and sizes..

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100,size=(100))
y = np.random.randint(100,size=(100))
colors = np.random.randint(100,size=(100))
sizes = 10*np.random.randint(100,size=(100))

plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# # **Matplotlib Bars**

# %% [markdown]
# to draw bar graphs use bar() function...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES","BANANAS"])
y = np.array([400,350])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ## **Horizontal Bars**

# %% [markdown]
# bars to be displayed horizontally by using barh() function..

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.barh(x,y)
plt.show()

# %% [markdown]
# ## **Bar Color**

# %% [markdown]
# To set bar color by using the keyword argument color...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.bar(x,y,color="red")
plt.show()

# %% [markdown]
# Draw 4 "hotpink" bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.bar(x,y,color="hotpink")
plt.show()

# %% [markdown]
# ## **Bar Width**

# %% [markdown]
# bar() takes the keyword argument width...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.bar(x,y,width=0.1) # default width value is 0.8
plt.show()

# %% [markdown]
# ## **Bar Height**

# %% [markdown]
# barh() takes the keyword height..

# %% [markdown]
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.barh(x,y,height=0.1) # default height value is 0.8
plt.show()

# %% [markdown]
# # **Matplotlib Histograms**

# %% [markdown]
# use hist() function to create histograms in matplotlib..

# %%
import numpy as np
x = np.random.normal(170,10,250)
print(x)
# Out:
# [171.95986733 173.42278496 146.68071737 171.99004643 186.44056576
#  163.73073228 189.42452411 179.62229937 181.45667137 170.40038938
#  180.01988594 183.61529848 172.80076901 167.31875404 157.33724385
#  169.79067796 164.13543732 176.55664985 160.68853907 160.82703321
#  170.87514702 165.80996984 171.09954709 156.84513702 166.53061457
#  180.38234514 167.79756075 181.05458771 175.24836167 177.42843252
#  168.08160229 183.22484934 161.91704661 168.52962001 177.6001762
#  172.80538964 167.25845685 155.27470601 183.41325029 152.16322607
#  199.95201876 181.3645129  174.33144917 172.12475369 161.18875581
#  162.6264176  165.61250743 161.49230246 197.63220694 183.93134177
#  162.78360598 172.82410284 177.06688915 175.33550811 150.20572323
#  177.74120517 153.22005165 154.51328205 164.81535316 187.44787354
#  164.56593276 157.49844846 158.71682899 178.88310463 168.44298074
#  163.83342088 170.5853986  163.0808465  177.22198586 174.48464182
# ...

# %% [markdown]
# we cant understand the above output..so we use hist() function will read the array and produce histogram..

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %% [markdown]
# # **Matplotlib Pie Charts**

# %% [markdown]
# use pie() function to draw pie chart in pyplot..

# %% [markdown]
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])

plt.pie(y)
plt.show()

# %% [markdown]
# ## **Labels**

# %% [markdown]
# use label parameter..

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]

plt.pie(y,labels=mylabels)
plt.show()
# move in counterclockwise

# %% [markdown]
# ## **Start Angle**

# %% [markdown]
# use startangle parameter..

# %% [markdown]
# start the first wedge at 90 degrees..

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]

plt.pie(y,labels=mylabels,startangle=90)
plt.show()

# %% [markdown]
# ## **Explode**

# %% [markdown]
# Pull the "APPLES" wedge 0.2 from the center of the pie:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
myexplode = [0.2,0,0,0]

plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %% [markdown]
# ## **Shadow**

# %% [markdown]
# add a shadow by using shadow parameter to true....

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
myexplode = [0.2,0,0,0]

plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# ## **Colors**

# %% [markdown]
# Specify a new color for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]
mycolors = ["black","hotpink","b","#4CAF50"]

plt.pie(y,labels=mylabels,colors=mycolors)
plt.show()

# %% [markdown]
# ## **Legend**

# %% [markdown]
# To add a list of explanation for each wedge ; use legend() function :

# %% [markdown]
# Add a legend:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]

plt.pie(y,labels=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## **Legend with Header**

# %% [markdown]
# To add a header to the legend , add a title parameter to the legend function:

# %% [markdown]
# add a legend with a header..

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,25,25,15])
mylabels = ["Apples","Bananas","Cherries","Dates"]

plt.pie(y,labels=mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# # **Waffle Chart**

# %% [markdown]
# It is a square display consisting of 100 smaller squares arranged in a 10 by 10 layout..

# %%
# !pip install pywaffle
# Out:
# ...
#   Using cached pywaffle-1.1.1-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached fontawesomefree-6.6.0-py3-none-any.whl.metadata (853 bytes)
# ...
# Using cached pywaffle-1.1.1-py2.py3-none-any.whl (30 kB)
# Using cached fontawesomefree-6.6.0-py3-none-any.whl (25.6 MB)
# ...

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle

fig = plt.figure(FigureClass=Waffle,rows=5,columns=10,values=[48,46,6],figsize=(5,3))

plt.show()
# Out:
# <Waffle size 500x300 with 1 Axes>

# %% [markdown]
# ## **Values in dict & Auto-sizing**

# %%
data = {'Democratic':48,'Republican':46,'Libertarian':3}

fig = plt.figure(FigureClass=Waffle,rows=5,
                 values=data,
                 legend={'loc':'upper left','bbox_to_anchor':(1.1,1)})

plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# ## **Title,Legend,Colors,Background color,Block color,Direction and Style**

# %%
data = {'Democratic':48,'Republican':46,'Libertarian':3}

fig = plt.figure(FigureClass=Waffle,rows=5,
                 values=data,
                 colors=["#232066","#983D3D","#DCB732"],
                 title={'label':'Vote Percentage in 2016 US Presidential Election','loc':'left'},
                 labels=[f"{k}({v}%)" for k,v in data.items()],
                 legend={'loc':'lower left','bbox_to_anchor':(0,-0.4),'ncol':len(data),'framealpha':0},

                 block_arranging_style='snake')

fig.set_facecolor('#EEEEEE')
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data = {'Democratic':48,'Republican':46,'Libertarian':3}

fig = plt.figure(FigureClass=Waffle,rows=5,
                 values=data,
                 colors=["#2317ad","#c90a53","#e89607"],
                 title={'label':'Vote Percentage in 2016 US Presidential Election','loc':'left'},
                 labels=[f"{k}({v}%)" for k,v in data.items()],
                 legend={'loc':'lower left','bbox_to_anchor':(0,-0.4),'ncol':len(data),'framealpha':0},

                 block_arranging_style='snake')

fig.set_facecolor('#f5ce9f')
plt.show() # here we take the color in color picker in google search...
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# # **Plot with Icons - Pictogram Chart**

# %%
data = {'Democratic':48,'Republican':46,'Libertarian':3}

fig = plt.figure(FigureClass=Waffle,rows=5,
                 values=data,
                 colors=["#232066","#983D3D","#DCB732"],
                 legend={'loc':'upper left','bbox_to_anchor':(1,1)},
                 icons='child',
                 font_size=12,
                 icon_legend=True)

plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# # **Word Cloud**

# %%
# !pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = ("oh oh oh oh oh oh verse wrote book stand title book would life superman that make feel count privilege love deal honored know feel see everyday things things say rock baby truth rock love rock rock everything need rock baby rock wanna kiss ya please ya right wanna touch ya love ya baby right ")

wordcloud = WordCloud(width=480,height=480,margin=0).generate(text)

plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
