# %% [markdown]
# # **1.Load and Inspect the Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/diamonds(EDA).csv')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# # **2.Understand the Data Types and Summary**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    50000 non-null  float64
#  5   table    50000 non-null  float64
#  6   price    50000 non-null  int64
#  7   x        50000 non-null  float64
#  8   y        50000 non-null  float64
#  9   z        50000 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %% [markdown]
# # **3. Data cleaning**

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (49874, 10)

# %% [markdown]
# # **4.Visualization**

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
# bar plot of cut and price...

plt.bar(df["cut"],df["price"])
plt.show()

# %%
# bar plot of color and price...

plt.bar(df["color"],df["price"])
plt.show()

# %%
# bar plot of color and carat..

plt.bar(df["color"],df["carat"])
plt.show()

# %%
#histplot of price..
df["price"].hist()
# Out:
# <Axes: >

# %%
# histogram of carat

plt.hist(df["carat"])
plt.show()

# %%
sns.countplot(data=df, x='cut', hue='clarity')
plt.show()

# %%
sns.histplot(df['price'], kde=True)
plt.show()

# %% [markdown]
# # **5. Correlation Analysis**

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49874 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    49874 non-null  float64
#  1   cut      49874 non-null  object
#  2   color    49874 non-null  object
#  3   clarity  49874 non-null  object
#  4   depth    49874 non-null  float64
#  5   table    49874 non-null  float64
#  6   price    49874 non-null  int64
#  7   x        49874 non-null  float64
#  8   y        49874 non-null  float64
#  9   z        49874 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.2+ MB

# %%
# labelencoder

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# df['cut'] = le.fit_transform(df['cut'])
# df['color'] = le.fit_transform(df['color'])
# df['clarity'] = le.fit_transform(df['clarity'])

# %%
print(df["cut"].unique()) # this is an ordinal dataset..
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
print(df["color"].unique()) # this is an ordinal dataset..
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %%
print(df["clarity"].unique())# this is an ordinal dataset..
# Out:
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
df["clarity"].replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[1,2,3,4,5,6,7,8],inplace=True) # replace clarity values in low to high order.so now it is not ordinal data.
# Out:
# /tmp/ipython-input-3525118119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["clarity"].replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[1,2,3,4,5,6,7,8],inplace=True) # replace clarity values in low to high order.so now it is not ordinal data.
# ...

# %%
df["color"].replace(['J', 'I', 'H', 'G', 'F', 'E', 'D'],[1,2,3,4,5,6,7],inplace=True)
# Out:
# /tmp/ipython-input-316582390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["color"].replace(['J', 'I', 'H', 'G', 'F', 'E', 'D'],[1,2,3,4,5,6,7],inplace=True)
# /tmp/ipython-input-316582390.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df["cut"].replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipython-input-3693530975.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cut"].replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[1,2,3,4,5],inplace=True)
# /tmp/ipython-input-3693530975.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    5      6        2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    4      6        3   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    2      6        5   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    4      2        4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2      1        2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    5      7        3   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    2      7        3   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    3      7        3   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    4      3        2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    5      7        2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %% [markdown]
# check correlation..

# %%
corr_matrix = df.corr()

sns.heatmap(corr_matrix , annot=True , fmt='0.01f' , cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# above price is target; x,y,z,carat has high collinearity,so take any one and drop others..we take carat..

df.drop(["x","y","z"],axis=1,inplace=True)

# %%
# check correlation between target 'price' with other columns..

price_corr = df.corr()['price']
price_corr = price_corr.drop('price') #remove correlation of price with itself(it is 1)

sns.heatmap(price_corr.to_frame() , annot=True , fmt='0.2f', cmap='coolwarm',cbar=True , annot_kws={'size':10})

plt.title('Correlation between Price and Other Features')
plt.show()

# %%
df.drop(["depth","cut"],axis=1,inplace=True)

# %% [markdown]
# # **6.outlier checking and removing**

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
      continue

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR= Q3-Q1

    lower_bound = Q1-1.5*IQR
    upper_bound = Q3+1.5*IQR

    df = df[(df[col]>=lower_bound) & (df[col]<=upper_bound)]

  return df

df_cleaned = remove_outliers_iqr(df,exclude_column='price')
df = df_cleaned

# %%
df.shape
# Out:
# (47595, 5)

# %% [markdown]
# # **7.Data scaling**

# %%
df
# Out:
#        carat  color  clarity  table  price
# 0       0.23      6        2   55.0    326
# 1       0.21      6        3   61.0    326
# 3       0.29      2        4   58.0    334
# 4       0.31      1        2   58.0    335
# 5       0.24      1        6   57.0    336
# ...      ...    ...      ...    ...    ...
# 49995   0.72      7        3   57.0   2757
# 49996   0.72      7        3   55.0   2757
# 49997   0.70      7        3   60.0   2757
# 49998   0.86      3        2   58.0   2757
# 49999   0.75      7        2   55.0   2757
#
# [47595 rows x 5 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

features = ['carat','color','clarity','table']

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(df[features])

scaled_df = pd.DataFrame(scaled_data,columns=features)

# %% [markdown]
# # **Prediction**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd

x = df[['carat','color','clarity','table']]
y = df['price']

x_train , x_test , y_train ,y_test = train_test_split(x ,y ,test_size=0.25 , random_state=42)

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.8918594719139397
